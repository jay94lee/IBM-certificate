# %% [markdown]
# <a href="https://colab.research.google.com/github/jay94lee/IBM-certificate/blob/main/offline_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch torchvision torchaudio

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.66 MiB | 21.35 MiB/s, done.
# Resolving deltas: 100% (10983/10983), done.

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# !pip install -r '/content/yolov5/requirements.txt'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import sys
sys.path.insert(0, "/content/yolov5/models")

import yolo

# %%
# This assumes you are in the YOLOv5 repository or have it in your Python path.
from models.yolo import DetectionModel

# Specify config
cfg = '/content/yolov5/models/yolov5s.yaml'  # Or path to your cfg file if not in running directory

# Initialize model
model = DetectionModel(cfg=cfg)

# Load pre-trained weights
weights = '/content/yolov5s.pt'  # Or path to your weights file if not in running directory
state_dict = torch.load(weights)['model']
model.load_state_dict(state_dict, strict=False)
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
# ...

# %%
weights = '/content/yolov5s.pt'
loaded_weights = torch.load(weights)

print("Type of loaded weights:", type(loaded_weights))
# Out:
# Type of loaded weights: <class 'dict'>

# %%
print("Keys in loaded weights:", loaded_weights.keys())
# Out:
# Keys in loaded weights: dict_keys(['epoch', 'best_fitness', 'model', 'ema', 'updates', 'optimizer', 'wandb_id', 'date'])

# %%
# This assumes you are in the YOLOv5 repository or have it in your Python path.
from models.yolo import DetectionModel

# Specify config
cfg = '/content/yolov5/models/yolov5s.yaml'  # Or path to your cfg file if not in running directory

# Initialize model
model = DetectionModel(cfg=cfg)
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
# ...

# %%
state_dict = loaded_weights['model']  # Extracting the state_dict

# %%
state_dict
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
state_dict = loaded_weights['model']  # Extracting the state_dict
model.load_state_dict(state_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-0bf9044b4bd1> in <cell line: 2>()
#       1 state_dict = loaded_weights['model']  # Extracting the state_dict
# ----> 2 model.load_state_dict(state_dict)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1992         """
#    1993         if not isinstance(state_dict, Mapping):
# -> 1994             raise TypeError("Expected state_dict to be dict-like, got {}.".format(type(state_dict)))
#    1995
#    1996         missing_keys: List[str] = []
#
# TypeError: Expected state_dict to be dict-like, got <class 'models.yolo.DetectionModel'>.

# %%
from models.yolo import DetectionModel

model = DetectionModel(cfg='/content/yolov5/models/yolov5s.yaml')

# %%
img = 'https://imengine.prod.srp.navigacloud.com/?uuid=6603EBF6-20D8-483C-AE64-8FA540E611EF&type=primary&q=72&width=1024'

# %%
results = DetectionModel(img)
results.print()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-44e5601ca5d4> in <cell line: 1>()
# ----> 1 results = DetectionModel(img)
#       2 results.print()
#
# /content/yolov5/models/yolo.py in __init__(self, cfg, ch, nc, anchors)
#     172             import yaml  # for torch hub
#     173             self.yaml_file = Path(cfg).name
# --> 174             with open(cfg, encoding='ascii', errors='ignore') as f:
#     175                 self.yaml = yaml.safe_load(f)  # model dict
#     176
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://imengine.prod.srp.navigacloud.com/?uuid=6603EBF6-20D8-483C-AE64-8FA540E611EF&type=primary&q=72&width=1024'

# %%
from  hubconf import custom
model = custom(path='/content/yolov5s.pt')  # custom example
# model = create(name='yolov7', pretrained=True, channels=3, classes=80, autoshape=True)  # pretrained example
# Out:
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 694x1023 4 persons, 1 car, 1 fire hydrant, 2 stop signs, 1 backpack
# Speed: 272.7ms pre-process, 11.6ms inference, 2.2ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
